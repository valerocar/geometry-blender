# %%
import sys
sys.path.append("..")
from gblend.geometry import *

import graphics.d3 as g3d
import graphics.d2 as g2d

from sympy import pi
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Creating triangle from 3 semi-planes
k= 1/16
h1 = HalfPlane2D(0,0,1,0,k=k)
h2 = HalfPlane2D(1,0,1,1,k=k)
h3 = HalfPlane2D(1,1,0,0,k=k)
h = h1 & h2 & h3
l = 1.5
domain = [-1,2,-1,2]
g3d.plot_data([g3d.function_graph(h.get_lambda(),domain=domain)])
# Out:
# <div>                            <div id="318ee125-ff66-4440-a056-29e2395d0cee" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("318ee125-ff66-4440-a056-29e2395d0cee")) {                    Plotly.newPlot(                        "318ee125-ff66-4440-a056-29e2395d0cee",                        [{"colorscale": [[0.0, "rgb(180,180,180)"], [1.0, "rgb(180,180,180)"]], "lighting": {"ambient": 0.4, "diffuse": 0.6, "roughness": 0.4, "specular": 0.14}, "lightposition": {"x": 10000, "y": 10000, "z": 50}, "opacity": 1.0, "showscale": false, "type": "surface", "x": [[-1.0, -0.9696969696969697, -0.9393939393939394, -0.9090909090909091, -0.8787878787878788, -0.8484848484848485, -0.8181818181818181, -0.7878787878787878, -0.7575757575757576, -0.7272727272727273, -0.
# ...
