# %%
import sys
sys.path.append("..")
from gblend.geometry import *
from gblend.variables import z,r

import graphics.d3 as r3d
from sympy import pi
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
obj = RevolutionSurface3D(1-z**6-(rxy-2)**6)
res = 50 # resolution for extracting mesh
sz = 3
mesh, trace = r3d.geometry_mesh_and_trace(obj,[-sz,sz,-sz,sz,-sz,sz], [res,res,res])
r3d.plot_data([mesh])
